# %% [markdown]
# ###### Import necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###### Load data to dataframe

# %%
store_data = pd.read_csv('shopify_intern_data.csv')

# %%
# Having a look at the column names, data types 
store_data.head()
# Out:
#    order_id  shop_id  user_id  ...  payment_method           created_at item_price
# 0         1       53      746  ...            cash  2017-03-13 12:36:56      112.0
# 1         2       92      925  ...            cash  2017-03-03 17:38:52       90.0
# 2         3       44      861  ...            cash   2017-03-14 4:23:56      144.0
# 3         4       18      935  ...     credit_card  2017-03-26 12:43:37      156.0
# 4         5       18      883  ...     credit_card   2017-03-01 4:35:11      156.0
#
# [5 rows x 8 columns]

# %%
# Lets have a brief look at the data types, as well as some likely relevant properties of each column 
print("--Table details--")
print(store_data.dtypes)

print("--Top 5 shops in terms of number of orders--")
print(store_data['shop_id'].value_counts().sort_values(ascending=False)[:5])

print("--Top 5 shops in terms of total order value--")
print(store_data.groupby(by="shop_id", dropna=False).sum()['order_amount'].sort_values(ascending=False)[:5])

print("--Most Recurrent Customer--")
print(store_data['user_id'].value_counts()[:5].sort_values(ascending=False))

print("--Highest Priced Item--")
store_data['item_price'] = store_data['order_amount']/store_data['total_items']
# Out:
# --Table details--
# order_id            int64
# shop_id             int64
# user_id             int64
# order_amount        int64
# total_items         int64
# payment_method     object
# created_at         object
# item_price        float64
# dtype: object
# --Top 5 shops in terms of number of orders--
# 53    68
# 71    66
# 19    64
# 13    63
# 89    61
# Name: shop_id, dtype: int64
# --Top 5 shops in terms of order value--
# shop_id
# 42    11990176
# 78     2263800
# 89       23128
# 81       22656
# 6        22627
# Name: order_amount, dtype: int64
# --Most Recurrent Customer--
# 718    28
# 868    27
# 791    26
# 847    26
# 727    25
# Name: user_id, dtype: int64
# --Highest Priced Item--

# %%
store_data.loc[store_data.shop_id==42]
# Out:
#       order_id  shop_id  ...           created_at  item_price
# 15          16       42  ...   2017-03-07 4:00:00       352.0
# 40          41       42  ...  2017-03-24 14:15:41       352.0
# 60          61       42  ...   2017-03-04 4:00:00       352.0
# 308        309       42  ...  2017-03-11 18:14:39       352.0
# 409        410       42  ...  2017-03-04 14:32:58       352.0
# 520        521       42  ...   2017-03-02 4:00:00       352.0
# 834        835       42  ...  2017-03-25 21:31:25       352.0
# 835        836       42  ...  2017-03-09 14:15:15       352.0
# 938        939       42  ...  2017-03-13 23:43:45       352.0
# 979        980       42  ...  2017-03-12 13:09:04       352.0
# 1104      1105       42  ...   2017-03-24 4:00:00       352.0
# 1362      1363       42  ...   2017-03-15 4:00:00       352.0
# 1364      1365       42  ...   2017-03-10 6:28:21       352.0
# 1367      1368       42  ...   2017-03-13 2:38:34       352.0
# 352        353       95  ...  2017-03-14 18:44:56       168.0
# 390        391        7  ...  2017-03-20 17:25:11       112.0
# 606        607       46  ...   2017-03-26 0:24:52       166.0
# 618        619       29  ...  2017-03-08 18:56:18       163.0
# 1072      1073       35  ...  2017-03-22 23:43:32       164.0
# 1142      1143       45  ...  2017-03-24 16:20:45       142.0
# 1266      1267       22  ...  2017-03-11 10:34:31       146.0
# 1416      1417        4  ...   2017-03-21 8:11:27       128.0
# 1514      1515       31  ...   2017-03-13 6:14:52       129.0
# 1577      1578       17  ...  2017-03-09 21:36:32       176.0
# 1815      1816       95  ...  2017-03-03 21:48:05       168.0
# 2108      2109       58  ...   2017-03-01 0:47:54       138.0
# 2624      2625       65  ...  2017-03-15 11:18:35       154.0
# 2847      2848       19  ...  2017-03-05 11:52:01       163.0
# 3177      3178       43  ...  2017-03-08 10:24:58       181.0
# 3432      3433       89  ...  2017-03-15 17:44:58       196.0
# 3543      3544        6  ...   2017-03-26 0:12:41       187.0
# 3563      3564       71  ...   2017-03-11 3:15:33       164.0
# 3580      3581       50  ...   2017-03-16 7:45:47       193.0
# 3673      3674        7  ...   2017-03-09 3:13:26       112.0
# 3773      3774       87  ...  2017-03-05 15:29:36       149.0
# 3794      3795       45  ...   2017-03-25 7:12:12       142.0
# 4039      4040       32  ...   2017-03-01 3:06:05       101.0
# 4293      4294       81  ...  2017-03-29 22:35:08       177.0
# 4572      4573       48  ...   2017-03-28 6:53:01       117.0
#
# [28 rows x 8 columns]

# %%
store_data['item_price'] = store_data['order_amount']/store_data['total_items']

# %%
# Out:
# 53    68
# 71    66
# 19    64
# 13    63
# 89    61
#       ..
# 74    38
# 56    37
# 67    37
# 38    35
# 85    35
# Name: shop_id, Length: 100, dtype: int64

# %%
sum(store_data['order_amount'])/len(store_data)
# Out:
# 3145.128

# %%
sum(store_data['order_amount']/store_data['total_items'])
# Out:
# 1938714.0

# %%
store_data['order_amount'].describe()
# Out:
# count      5000.000000
# mean       3145.128000
# std       41282.539349
# min          90.000000
# 25%         163.000000
# 50%         284.000000
# 75%         390.000000
# max      704000.000000
# Name: order_amount, dtype: float64

# %%
plt.boxplot(store_data['order_amount'])
fig = plt.figure(figsize =(10, 7))
plt.show()

# %%
plt.hist(store_data['order_amount'])
fig = plt.figure(figsize =(10, 7))
plt.show()

# %%
plt.boxplot(store_data.loc[store_data['order_amount']!=store_data['order_amount'].max()]['order_amount'])
fig = plt.figure(figsize =(10, 7))
plt.show()

# %%
store_data['order_amount']


plt.boxplot(store_data['order_amount'])
fig = plt.figure(figsize =(10, 7))
plt.show()
